# %%
import pandas as pd
from pandas.core.frame import DataFrame
import datetime
import time
import re
import networkx as nx
import matplotlib.pyplot as plt
from newspaper import Article

# %%
def Newslogs_preprocessing(Newslogs):
    def clean_url(article_url):
        def clean_CHT_url(url):
            if '?chdtv' in url: url = url.replace('?chdtv', '')
            if '?ctrack' in url: url = url[:url.find('?ctrack')]
            return url
        def clean_LBT_url(url):
            if '?utm_source' in url: url = url[:url.find('?utm_source')]
            return url
        if 'chinatimes.com/' in article_url: return clean_CHT_url(article_url)
        if 'ltn.com.tw/' in article_url: return clean_LBT_url(article_url)
    
    Newslogs = [[clean_url(k[0]), k[1], k[2], k[3]] for k in Newslogs]
    Newslogs.reverse()
    return Newslogs

# %%
Newslogs = pd.read_csv('/Users/gtingyou/Desktop/firefox_history.csv', encoding='utf8', header=0).values.tolist()
Newslogs = Newslogs_preprocessing(Newslogs)
TODAY_DATE = time.strftime('%Y-%m-%d',datetime.datetime.timetuple(datetime.datetime.now()))
USERINDEX = 'user1'

# %%
def create_user_network_nodes(Newslogs, USERINDEX, TODAY_DATE):
    def check_parse_news_details_or_not(article_url) -> bool:
        """Check whether the url is linked to a news or not.
           It returns a bool ->
               True: If the url linked to a news.
               False: If the url doesnt linked to a news, such as a frontpage.
        """
        if 'ltn.com.tw/' in article_url:
            if re.match('https://([a-z]*?).ltn.com.tw/(.*?)/(\d{7})', article_url)!=None:
                return True
            else:
                print('***PAGE NOT NEED DETAILS***\n', article_url)
                return False
        elif 'chinatimes.com/' in article_url:
            def clean_CHT_url(url):
                if '?chdtv' in url: url = url.replace('?chdtv', '')
                if '?ctrack' in url: url = url[:url.find('?ctrack')]
                return url
            article_url = clean_CHT_url(article_url)
            if re.match('https://www.chinatimes.com/(.*?)/(\d{14}-\d{6})', article_url)!=None:
                return True
            else:
                print('***PAGE NOT NEED DETAILS***\n', article_url)
                return False
            
    def get_news_details(article_url, NEWSINDEX, TODAY_DATE):
        """Parse News details, including NewsUrl, PublishDate, NewsTitle and NewsContent.
           It returns
               a list -> news_details: [NewsIndex, ParseDate, NewsUrl, PublishDate, NewsTitle, NewsContent]
               and an int -> NEWSINDEX: Records the NewsIndex
        """
        if check_parse_news_details_or_not(article_url)==True:
            article = Article(article_url)
            try:
                print('***DOWNLOADING***\n', article_url)
                article.download()
                article.parse()
            except:
                print('***FAILED TO DOWNLOAD***\n', article_url)
                return False
            article_date = str(article.publish_date)[:10]

            NEWSINDEX+=1
            news_details = [USERINDEX+'_'+str(NEWSINDEX), TODAY_DATE, article_url, article_date, article.title, article.text]
            return news_details, NEWSINDEX

        elif check_parse_news_detail_or_not(article_url)==False:
            news_details = [article_url, TODAY_DATE, article_url, '', '', '']
            return news_details, NEWSINDEX
        
        
    NEWSINDEX = 0
    user_network_nodes = []
    ### 抓出瀏覽紀錄中不重複的 url
    Newslogs_unique_urls = []
    for log in Newslogs:
        if log[0] not in Newslogs_unique_urls:
            Newslogs_unique_urls.append(log[0])
    ### 針對不重複的 url，爬詳細新聞資料
    for article_url in Newslogs_unique_urls:
        news_details, NEWSINDEX = get_news_details(article_url, NEWSINDEX, TODAY_DATE)
        user_network_nodes.append(news_details)
    return user_network_nodes

# %%
def create_user_network_edges(Newslogs, user_network_nodes):
    user_network_edges = []
    for i in range(0, len(Newslogs)-1):
        url_1 = Newslogs[i][0]
        url_2 = Newslogs[i+1][0]
#         print('-'*50+'\n%s\n%s' %(url_1, url_2))
        user_network_nodes_urls = [k[2] for k in user_network_nodes]
        if url_1 in user_network_nodes_urls and url_2 in user_network_nodes_urls:
            c1 = user_network_nodes[user_network_nodes_urls.index(url_1)][0]
            c2 = user_network_nodes[user_network_nodes_urls.index(url_2)][0]
            
            ### 取比較大的時間作為瀏覽時間
            d1 = datetime.datetime.strptime(Newslogs[i][2], "%Y-%m-%d %H:%M:%S")
            d2 = datetime.datetime.strptime(Newslogs[i+1][2], "%Y-%m-%d %H:%M:%S")
            if d1>=d2: parse_date=Newslogs[i][2]
            else: parse_date=Newslogs[i+1][2]
            
            user_network_edges.append([c1, c2, parse_date])
#             print(c1, c2)
    return user_network_edges

# %%
user_network_nodes = create_user_network_nodes(Newslogs, USERINDEX, TODAY_DATE)
# Out:
# ***PAGE NOT NEED DETAILS***
#  https://www.chinatimes.com/
# ***PAGE NOT NEED DETAILS***
#  https://www.chinatimes.com/
# ***DOWNLOADING***
#  https://www.chinatimes.com/realtimenews/20200622001567-260405
# ***DOWNLOADING***
#  https://www.chinatimes.com/realtimenews/20200622002688-260405
# ***PAGE NOT NEED DETAILS***
#  https://news.ltn.com.tw/list/breakingnews
# ***PAGE NOT NEED DETAILS***
#  https://news.ltn.com.tw/list/breakingnews
# ***PAGE NOT NEED DETAILS***
#  https://sports.ltn.com.tw/
# ***PAGE NOT NEED DETAILS***
#  https://sports.ltn.com.tw/
# ***DOWNLOADING***
#  https://sports.ltn.com.tw/news/paper/1381483
# ***DOWNLOADING***
#  https://sports.ltn.com.tw/news/paper/1381484
# ***DOWNLOADING***
#  https://www.chinatimes.com/realtimenews/20200624003302-260409
# ***DOWNLOADING***
#  https://www.chinatimes.com/realtimenews/20200624002599-260409
# ***DOWNLOADING***
#  https://www.chinatimes.com/realtimenews/20200624000070-260409
# ***PAGE NOT NEED DETAILS***
#  https://www.chinatimes.com/realtimenews/
# ***PAGE NOT NEED DETAILS***
#  https://www.chinatimes.com/realtimenews/
# ***PAGE NOT NEED DETAILS***
#  https://covid-19.chinatimes.com/%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E,%E5%8F%B0%E7%81%A3
# ***PAGE NOT NEED DETAILS***
#  https://covid-19.chinatimes.com/%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E,%E5%8F%B0%E7%81%A3
# ***DOWNLOADING***
#  https://www.chinatimes.com/realtimenews/20200624003186-260405
# ***DOWNLOADING***
#  https://www.chinatimes.com/realtimenews/20200620003247-260405
# ***PAGE NOT NEED DETAILS***
#  https://www.ltn.com.tw/
# ***PAGE NOT NEED DETAILS***
#  https://www.ltn.com.tw/
# ***DOWNLOADING***
#  https://health.ltn.com.tw/article/breakingnews/3207818
# ***DOWNLOADING***
#  https://health.ltn.com.tw/article/breakingnews/3200518
# ***PAGE NOT NEED DETAILS***
#   '端午連假即將到來，消費者依然關心哪裡可以搶口罩，量販超市在端午前夕紛紛推出加碼促銷，今明（ 22、23 ）兩天屈臣氏將開賣特殊色中衛口罩。家樂福21日已開賣第3波口罩，還有滿額折扣及熱門商品買一送一。\n\n●屈臣氏：\n\n屈臣氏網路商店今明兩天早上將開賣網路限定的中衛盒裝醫療口罩，顏色除了熱門的酷黑、深丹寧色外，還新增了青蘋綠、櫻花粉與軍綠等特殊新色，兩天共計販售 3510 盒。\n\n●康是美：\n\n康是美開賣 MIT 台灣製造的「恒大醫用口罩」，單盒 50 片裝，售價 299 元，每人限購 1 盒，預計將於 6 月 26 及 7 月 3 日兩天各陸續上架 200 萬片。\n\n●蝦皮購物：\n\n蝦皮購物每天下午 5 點在蝦皮超市限量開賣 MIT 醫療口罩，單盒 50 片入，不挑色，售價399元，每人每天限購 1 盒。\n\n●Yahoo奇摩購物中心：\n\n每天中午 11 點至 12 點不定時開賣成人醫療口罩，品牌包含：中衛、MOTEX 摩戴舒、匠心等，每人限購 1 盒，售價依網站公告。\n\n●家樂福\n\n第3波MIT口罩6月21日已開賣，172,500片「順易利醫用口罩」 成人款，50入（盒）299元，總計有3450盒將分配到家樂福全台68家量販店販售(每人限買1盒)。\n\n(中時電子報)'],
#  ['user1_2',
#   '2020-06-24',
#   'https://www.chinatimes.com/realtimenews/20200622002688-260405',
#   '2020-06-22',
#   '好市多中衛口罩又秒殺！民眾哭：一直按一直按 - 生活',
#   '櫻花粉、青蘋綠等「中衛醫療彩色口罩」超搶手，除了屈臣氏之外，好市多官網也宣布開賣！不過一開賣就被秒殺，有消費者表示一直按加入購物車都無法，網站只顯示「庫存不足」。\n\n好市多線上平台販售的「中衛醫療彩色口罩」一盒50片265元，平均一片5.3元，有天空藍、酷黑、薰衣紫、炫霓紫、軍綠色，但顏色無法指定、採隨機出貨，每卡限購1組。(圖/截自好市多官網)\n\n好市多線上平台販售的「中衛醫療彩色口罩」，一盒50片265元，平均一片5.3元，有天空藍、酷黑、薰衣紫、炫霓紫、軍綠色，但顏色無法指定、採隨機出貨，每卡限購1組。\n\n醫療口罩解禁後更搶手，包括超商、賣場及電商平台等通路，口罩幾乎都是一上架就被秒殺，好市多今天才宣布線上平台開搶中衛口罩沒多久，網站上已顯示庫存不足，有民眾一直按加入購物車，都無法完成，只能望口罩興嘆。\n\n沒搶到的也別灰心，今明兩天屈臣氏網路商店也可以購買酷黑、深丹寧、青蘋綠、櫻花粉與軍綠等特殊新色的中衛口罩，此外，還有Yahoo奇摩購物中心，每日上午11點到12點不定時開賣成人醫療口罩，品牌有中衛、MOTEX摩戴舒、匠心等，每人限購一盒。蝦皮購物每日下午5點限量開賣MIT醫療口罩，單盒50片399元，每人每日限購1盒。\n\n(中時電子報)'],
#  ['https://news.ltn.com.tw/list/breakingnews',
#   '2020-06-24',
#   'https://news.ltn.com.tw/list/breakingnews',
#   '',
#   '',
#   ''],
#  ['https://sports.ltn.com.tw/',
#   '2020-06-24',
#   'https://sports.ltn.com.tw/',
#   '',
#   '',
#   ''],
#  ['user1_3',
#   '2020-06-24',
#   'https://sports.ltn.com.tw/news/paper/1381483',
#   'None',
#   '巨人3連勝 岱桑2安助陣',
#   ''],
#  ['user1_4',
#   '2020-06-24',
#   'https://sports.ltn.com.tw/news/paper/1381484',
#   'None',
#   '大聯盟春訓基地全關 洋基也中鏢',
#   ''],
#  ['user1_5',
#   '2020-06-24',
#   'https://www.chinatimes.com/realtimenews/20200624003302-260409',
#   '2020-06-24',
#   '陸布置北斗衛星背後 4000億人幣位置市場爆發 - 兩岸',
#   '大陸第55顆北斗導航衛星6月23日成功發射，北斗三號全球衛星導航系統星座部署全面完成。而中國衛星導航定位協會5月發佈的《2020中國衛星導航與位置服務產業發展白皮書》顯示，2019年大陸衛星導航與位置服務產業總體產值達到將近3450億元（人民幣，下同），年增率達14.4％，預計2020年產業總產值將超過4000億元。\n\n據《21世紀經濟報導》指出，在民用行業，北斗將深刻影響汽車、共用出行、地圖位置服務、手機、5G、物聯網、車聯網多個領域。衛星導航與位置服務的機遇即將來臨。\n\n現在社會中位置服務的重要性不言而喻。大陸航太科技集團五院、北斗三號衛星總設計師王平曾表示，日常生活中有人統計80％以上資訊都和位置、時間相關。而多數人印象中，全球定位系統（GPS）佔據主流市場，該系統從上個世紀的美國開始構造，也是目前成熟度最高、使用最悠久的導航系統。\n\n但大陸的北斗系統雖然起步較晚，卻一直追趕中。從2000年底建成北斗一號系統，到2012年年底建成北斗二號系統，再到2020年前後建成北斗全球系統，向全球提供服務，服務範圍不斷擴大。\n\n東興證券此前預計，北斗三號完成全面組網，下游應用市場將進入高速發展階段，至2020年，大陸衛星導航產業規模將超過4000億元，北斗將拉動超過3000億元規模，且在「一帶一路」倡議下，北斗導航作為基礎設施，將會在海外迎來更大的發展空間。\n\n(旺報 )'],
#  ['user1_6',
#   '2020-06-24',
#   'https://www.chinatimes.com/realtimenews/20200624002599-260409',
#   '2020-06-24',
#   '長江中上游暴雨今最凶險 三峽大壩全面蓄洪應急 - 兩岸',
#   '長江中上游連日暴雨，大陸中央氣象台預計今天降雨會達高峰，汛情不容樂觀，考驗長江三峽大壩防洪能力。中新社引述三峽集團指，因應嚴峻防洪形勢，三峽大壩水力發電站已全部開動運作，意味全面發揮攔洪蓄洪能力。\n\n中新社報導，三峽集團公佈指，截至週二（23日）10時，該集團長江幹流四座梯級電站——三峽、葛洲壩、溪洛渡、向家壩水電站共82台機組實現2020年首次全開運行發電，總出力達3953萬千瓦時。\n\n報導稱，今夏以來，面對嚴峻的防洪形勢，三峽集團長江電力嚴格執行國家防總、長江防總的調度指令，開展以三峽水庫爲核心的梯級水庫聯合調度，充分利用防洪庫容「攔洪蓄洪」能力，減緩洪峰，以保障長江流域防洪安全和人民群衆生命財產安全。\n\n三峽集團表示，會繼續密切關注上游流域水雨情變化，根據水流量和用電需求，決定蓄洪發電工作。\n\n央視新聞聯播週二晚上連續第2天報導，貴州至長江中下游地區豪雨不減，貴州、安徽中小型河川出現洪水及山洪爆發。大陸中央氣象台持續發布暴雨黃色預警。\n\n根據報導，中央氣象台預測，這波降雨今天將進入過程最強的時間。而24日降雨帶將整體南移，安徽、江蘇、雲南、貴州等省降雨雖會減弱，但湖南、廣西、江西等省區仍將有豪雨。\n\n報導指出，貴州省正經歷今年入汛以來最強的降雨，已正式啟動氣象災害暴雨2級應急響應。\n\n至於重慶市綦江區，1940年以來最大的洪水在週一（22日）晚間通過當地，水位週二（23日）上午退到警戒水位以下。\n\n而在湖南省災情較嚴重的懷化市，已啟動防汛3級應急響應。當地目前已出現道路、房屋受損，為此緊急遷移6萬餘人；至於安徽多條河川水位超過警戒線，其中嶽西縣更遭遇30年來最大降雨。\n\n(中時 )'],
#  ['user1_7',
#   '2020-06-24',
#   'https://www.chinatimes.com/realtimenews/20200624000070-260409',
#   '2020-06-24',
#   '沒有空調和電風扇 原來古人是這樣度過炎炎夏日 - 兩岸',
#   '對大多數人來說，炎炎夏日就是要躲在冷氣房內避暑，不過，在沒有空調跟電扇的時代，古人是如何度過炎熱的夏天呢？事實上，面對氣候變化，古人自有一套應對方式，早在周朝，人們就有挖鑿冰窖度暑的紀錄，唐朝更誕生了許多現代人常吃的夏季冰品。顯然，面對自然的挑戰，人類自會為生存找到一條出路。\n\n早在周朝，就誕生了一種叫「夏房」的屋子，在屋內，有許多奴婢輪流為貴族搧風，這成為相當早期的避暑方式。此外，周朝還發明一種叫做「冰鑑」的容器，這種容器最早是用於祭祀，後來才被拿來在夏季的室內使用。說到冰鑑，在該容器上方有個方形的蓋子，可以往內部添加冰塊，蓋上有兩個小孔，將蓋子蓋上後，冷氣會從兩孔中冒出，讓室內充滿涼氣，而冰鑑不只可當空調，還可當成冰箱。\n\n到了秦朝，秦始皇曾建過一座水晶宮，整個宮殿的柱子都是用水晶做成，內部可藏冰，到了夏天，涼氣就會透出柱子蔓延到整個宮殿；漢代也有類似的宮殿，叫做清涼殿，降溫原理與秦朝的水晶宮類似，不過製冷技術是有過之而無不及。\n\n到了唐代，也有一座含涼殿，傳說唐玄宗和楊貴妃就喜歡在裡面乘涼，含涼殿採用「全自動循環系統」，在屋頂有一個「扇車」，「扇車」發動時會對準水源，把冷水順著屋簷上的管道吹下去，在室內產生冷氣；為了防止水流下來的時候讓殿內積水，工匠們還做了一個可以循環流動的水管，安裝在宮殿的角落，把水重新引到屋簷上，然後再流動下去，這樣不用人為操作，含涼殿也可以永保清涼。\n\n不過，比起空調這類技術，民以食為天，冷飲及冰品的出現可能更讓人感到雀躍。早在商代，人們就有喝冷飲的紀錄；唐代則是冷飲的發展期，不僅有冰棍，還有用水果做成的酸梅湯、烏龍茶、桃花茶、薑茶、荔枝膏、紅茶水、椰子酒和用水果製成的奶茶。\n\n經濟繁榮的宋朝更是「吃貨橫行」的時代，比較著名的有「涼水」和「渴水」。涼水是指偏涼性的飲料，像是綠豆水、紫蘇飲、甘蔗汁等；渴水則類似於今日的濃縮飲料，不過比較健康，是用水果熬煮，有的還會加入了一些滋補身體的中藥，有木瓜渴水、楊梅渴水、葡萄渴水、丁香渴水等。\n\n(旺報 )'],
#  ['https://www.chinatimes.com/realtimenews/',
#   '2020-06-24',
#   'https://www.chinatimes.com/realtimenews/',
#   '',
#   '',
#   ''],
#  ['https://covid-19.chinatimes.com/%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E,%E5%8F%B0%E7%81%A3',
#   '2020-06-24',
#   'https://covid-19.chinatimes.com/%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E,%E5%8F%B0%E7%81%A3',
#   '',
#   '',
#   ''],
#  ['user1_8',
#   '2020-06-24',
#   'https://www.chinatimes.com/realtimenews/20200624003186-260405',
#  ['https://www.ltn.com.tw/',
#   '2020-06-24',
#   'https://www.ltn.com.tw/',
#   '',
#   '',
#   ''],
#  ['user1_10',
#   '2020-06-24',
#   'https://health.ltn.com.tw/article/breakingnews/3207818',
#   'None',
#   '想爬樓梯減重 小心膝痛先報到',
#   ''],
#  ['user1_11',
#   '2020-06-24',
#   'https://health.ltn.com.tw/article/breakingnews/3200518',
#   'None',
#   '健康網》傳離開北京班機全客滿 醫師憂：第二波病毒攻擊來了',
#   ''],
#  ['https://news.ltn.com.tw/list/breakingnews/popular',
#   '2020-06-24',
#   'https://news.ltn.com.tw/list/breakingnews/popular',
#   '',
#   '',
#   ''],
#  ['https://news.ltn.com.tw/list/breakingnews/politics',
#   '2020-06-24',
#   'https://news.ltn.com.tw/list/breakingnews/politics',
#   '',
#   '',
#   ''],
#  ['https://news.ltn.com.tw/list/breakingnews/life',
#   '2020-06-24',
#   'https://news.ltn.com.tw/list/breakingnews/life',
#   '',
#   '',
#   ''],
#  ['user1_12',
#   '2020-06-24',
#   'https://news.ltn.com.tw/news/politics/breakingnews/3208343',
#   '2020-06-24',
#   '拚選情？求平安？柯文哲端午連假屏東輔選1天跑11廟',
#   '柯文哲已連兩年在6月底訪屏東，圖為去年6月至車城福安宮參拜。（資料照，記者陳彥廷攝）\n\n2020-06-24 20:19:54\n\n〔記者陳彥廷／屏東報導〕台灣民眾黨與在地青年廖國富結盟投入崁頂鄉鄉長補選，該黨主席柯文哲端午連假赴崁頂鄉為廖國富輔選，是組黨後首次投入地方性選舉輔選，行程第二天更跑遍東港鎮及崁頂鄉的11間廟，展現全力力挺態度。\n\n廖國富雖以無黨籍登記，但獲得民眾黨大力輔選，民眾黨不分區立委蔡壁如、張其祿數度南下，除陪同登記外，隔天更找來水利署等單位視察崁頂的水文，輔選力道強勁，而本週末更將迎來台北市長、創黨黨主席柯文哲輔選。\n\n請繼續往下閱讀...\n\n日前蔡壁如就曾指出已安排柯文哲將於本週末將親自南下輔選，今天民眾黨媒體群組也發出採訪通知，柯文哲將於26、27日連兩天赴屏東輔選，地點除崁頂鄉外，鄰近的兩個大鎮潮州及東港，柯亦多所著墨。\n\n柯文哲26日先於崁頂與青農座談屏東農業產銷與品牌創新外，接著27日一早則會到大東港地區的信仰中心東隆宮參拜，緊接著下午於崁頂鄉的宮廟參拜求平安，整天參訪的宮廟達11間。\n\n由於昨天民眾黨才底定徵召親民黨籍的高雄市議員吳益政登記高雄市長補選，本週一連4天連假，預料除了屏東的行程外，柯文哲也將安排到高雄為吳益政輔選，黨主席親自出馬，一次走訪高、屏，又因屬柯文哲組黨後首次親自出馬輔選，還是首度投入行政首長的補選，可說是高雄市長補選的熱身賽，格外引發關注。\n\n不過，柯文哲組黨前的去年6月，亦曾赴恆春鎮，已連兩年選在6月底到屏東，而當時陪柯文哲伉儷「逛墾丁大街」的無黨籍前鎮長盧玉棟，因涉賄遭判當選無效，出缺要補選後民眾黨也曾表態不會放棄採與無黨籍在地人才結盟投入補選，但至今仍未傳出有鎖定何人，柯文哲應不會再赴恆春。\n\n不用抽 不用搶 現在用APP看新聞 保證天天中獎 點我下載APP 按我看活動辦法'],
#  ['https://market.ltn.com.tw/article/8382',
#   '2020-06-24',
#   'https://market.ltn.com.tw/article/8382',
#   '',
#   '',
#   ''],
#  ['user1_13',
#   '2020-06-24',
#   'https://news.ltn.com.tw/news/life/breakingnews/3208237',
#   '2020-06-24',
#   '日女確診恐本土個案？ 陳時中：「待釐清」暫不列案號',
#   '中央流行疫情指揮中心指揮官陳時中（見圖）表示，一名在台就學的20多歲日本女性返日入境檢疫確診武漢肺炎，該女為在南部就學，目前必須釐清檢驗結果，若後續釐清可能列為本土個案。（圖由中央流行疫情指揮中心提供）\n\n2020-06-24 18:49:32\n\n〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日5點半加碼召開記者會，公布一名20多歲在台就學的日本女性，返回日本入境時經檢驗確診武漢肺炎（新型冠狀病毒病，COVID-19），指揮官陳時中表示，該女為在南部就學，目前必須釐清檢驗結果，因此先不列案號，若後續釐清，可能列為本土個案。\n\n陳時中：從未排除有潛存本土個案\n\n指揮中心發言人莊人祥補充，要向日本取得該女檢驗結果，主要是因為該女無症狀，無從了解何時感染，必須要檢視數值，研判是否為近期感染，且也可能涉及假陽性，有待進一步確認。\n\n請繼續往下閱讀...\n\n對於此名個案出現是否代表國內有潛存的本土個案？陳時中強調，一直都沒有排除這個可能性，仍要提高警覺，但可能性很低，決定待釐清數值後，疫調就要開始啟動。\n\n初步掌握140接觸者 125人居家隔離\n\n目前針對該女在台期間接觸者初步掌握共140人，包括同校老師、學生及宿舍相關接觸者等，其中125人暫列為居家隔離對象、15人暫列為自主健康管理對象，將進一步調查個案校外活動軌跡以匡列其他可能之接觸者；另針對個案於我國機場所接觸的地勤、櫃檯及接待人員共4人，將持續進行自主健康管理至14天期滿。\n\n莊人祥也說明，針對125名居家隔離者，會全數進行檢驗，若再有確診個案，將立即對外公布，但研判可能性不高。\n\n相關新聞請見︰\n\n「武漢肺炎專區」請點此，更多相關訊息，帶您第一手掌握。\n\n不用抽 不用搶 現在用APP看新聞 保證天天中獎 點我下載APP 按我看活動辦法'],
#  ['user1_14',
#   '2020-06-24',
#   'https://news.ltn.com.tw/news/life/breakingnews/3208155',
#   '2020-06-24',
#   '日本女學生染疫有台灣旅遊史 陳時中︰在台接觸者至少140人',
#   '指揮官陳時中表示，這名染疫日本女性在南部就學，目前已匡列在台接觸者至少140人，縣市別待確認後可能會向外公布。（指揮中心提供）\n\n2020-06-24 17:46:27\n\n〔記者林惠琴／台北報導〕日本厚生勞動省宣布新增武漢肺炎（新型冠狀病毒病，COVID-19）個案中，有1名20多歲女性有台灣旅遊史，恐為國內本土疫情增添變數，中央流行疫情指揮中心今日5點半加碼召開記者會，指揮官陳時中表示，該女為在南部就學，目前已匡列在台接觸者至少140人，縣市別待確認後可能會向外公布。\n\n陳時中表示，我國昨日接獲日本官方透過國際衛生條例國家對口單位（IHR National Focal Point）通知，該國確診1名自我國返日的武漢肺炎無症狀感染者。\n\n請繼續往下閱讀...\n\n陳時中指出，經與日方密切聯繫，確認該名個案為日本籍20多歲女性，今年2月底自日本入境台灣，於南部就學，在台期間多於南部地區活動，上週搭機返回日本時，於入境採檢檢出新型冠狀病毒陽性；個案無症狀，由日方安排防疫旅館隔離中。\n\n由於該名個案於日本確診，衛生單位已啟動疫情調查、接觸者匡列及個案活動環境清消等防治措施，個案在台期間無參與學校社團或校外打工，截至目前為止初步掌握接觸者共140人，包括同校老師、學生及宿舍相關接觸者等，其中125人暫列為居家隔離對象、15人暫列為自主健康管理對象，將進一步調查個案校外活動軌跡以匡列其他可能之接觸者；另針對個案於我國機場所接觸的地勤、櫃檯及接待人員共4人，將持續進行自主健康管理至14天期滿。\n\n相關新聞請見︰\n\n「武漢肺炎專區」請點此，更多相關訊息，帶您第一手掌握。\n\n不用抽 不用搶 現在用APP看新聞 保證天天中獎 點我下載APP 按我看活動辦法'],
#  ['user1_15',
#   '2020-06-24',
#   'https://news.ltn.com.tw/news/world/breakingnews/3203519',
#   '2020-06-19',
#   '秋天解禁？ 日本首波開放入境國家沒台灣 日媒曝關鍵原因',
#   '日本首相安倍晉三18日宣布，將與越南、泰國、澳洲、紐西蘭等4國進行出入境鬆綁協商，但當中沒有提到台灣。（法新社資料照）\n\n2020-06-20 05:53:18\n\n首次上稿 00:11\n\n更新時間 05:53\n\n〔即時新聞／綜合報導〕日本首相安倍晉三18日宣布，將與越南、泰國、澳洲、紐西蘭等4國進行出入境鬆綁協商，但台灣卻未列入其中，引發日本網友好奇「名單沒有台灣讓人很訝異」。對此，有日媒報導，台灣可能在秋天之後才有望解禁，關鍵原因在於日本PCR檢測（RT-PCR，又稱病毒核酸檢驗法）的能力有限。\n\n請繼續往下閱讀...\n\n安倍晉三18日在武漢肺炎（新型冠狀病毒病，COVID-19）對策總部會議上表示，為了重振經濟，將逐步重啟邊境，目前首先與越南、泰國、澳洲與紐西蘭等4國疫情相對趨緩的國家進行出入境鬆綁協商，之後再依照國際疫情與日本的情況做調整，陸續開放其他國家與地區。\n\n日本首波鬆綁名單中不見台灣，引起不少人的好奇，就有日本網友認為「名單沒有台灣讓人很訝異」、「有泰國、澳洲卻沒有台灣？」、「是怕允許台灣引起中國抗議嗎？」\n\n據《日本經濟新聞》 報導，越南、泰國、澳洲和紐西蘭這4個國家，2018年日均入境人數約為6000人，但美國、韓國、中國及台灣的日均入境人數為6.1萬人，其中台灣就佔了1萬3千，4個國家佔總入境人數的7成。\n\n報導指出，雖然台灣等4個國家與日本經濟往來密切，卻未列入首波入境名單，其實關鍵在於日本的PCR檢查能量有限。據報導，日本機場每日檢查能力最多僅2300人，最近每天檢查數約950人，因此現階段限制單日最多開放250人入境，還能負荷得了。\n\n《日本經濟新聞》因此研判，台灣人要入境日本，可能要到秋天才有望解禁。\n\n相關新聞請見︰\n\n「武漢肺炎專區」請點此，更多相關訊息，帶您第一手掌握。\n\n不用抽 不用搶 現在用APP看新聞 保證天天中獎 點我下載APP 按我看活動辦法'],
#  ['user1_16',
#   '2020-06-24',
#   'https://news.ltn.com.tw/news/world/breakingnews/3199993',
#   '2020-06-16',
#   '武漢肺炎》北京耳語滿天飛！傳醫院爆滿、染疫屍體天天燒',
#   '北京自11日以來已累計106人確診病例，官方15日宣布，北京全市社區防控工作進入「戰時狀態」，並展開「敲門行動」大排查；16日晚間，北京市政府舉行記者會，宣布北京市突發公共衛生事件應急響應級別由三級調至二級，並相應調整防控策略。圖為曾至「新發地批發市場」的北京市民排隊接受病毒篩檢。（法新社資料照）\n\n2020-06-17 00:14:04\n\n〔即時新聞／綜合報導〕中國北京武漢肺炎（新型冠狀病毒病，COVID-19）疫情復燃，自11日以來已逾百例病例，15日官方宣布全市進入「戰時狀態」，16日更由三級應急響應上調至二級。有北京市民透露，殯儀館每天都在燒染疫死者屍體，甚至傳出多家軍隊、武警醫院爆滿，還有醫院因此封院。\n\n根據《希望之聲》 報導，北京市民朱先生受訪透露，他有朋友在殯儀館工作，近日殯儀館每天都有因武漢肺炎致死的屍體等待焚燒，「工作人員燒屍的時候，都是全副武裝進去的。要是正常死亡的人，他們只是穿著工作服進去的，在焚燒爐裡燒人。這穿的不一樣啊。把屍體拉進去有專人處理染疫死亡的屍體。」朱先生說，友人不敢透露太多，因為他也擔心被逮捕。\n\n請繼續往下閱讀...\n\n另名市民郝先生質疑，北京疫情並非二次爆發，而是中共一直隱瞞不報，「其實我都懷疑，從一開始到現在，這個疫情它就沒有消停過，當局為了穩住以後它不報了。現在一看世界上到處各個國家還在報著，那是不是隱瞞不住了？」\n\n而市民洪先生則透露，他15日下午收到群組消息，要求做核酸檢測，但有好多人沒有參加檢測就落跑了，「不知道為什麼早就跑了，開著車這一溜煙兒從房山就出去了」。\n\n前中國《經濟學週報》副總編輯、北京獨立記者高瑜15日也在推特推文指稱，永定路、鐵建、西里、六建、嘉德公寓、白朗園、十一院、二院、國防大學2號院已經全部封閉，另外許多醫院也相應成爲重災區和聚集性感染源頭，如721醫院、武警醫院都正在進行核酸排查。\n\n高瑜在另篇推文稱，「國防大學2號院封閉。昨天院內服務區賣肉的與玉泉東市場一個賣肉的有聯繫，兩人都確診。他們都從新發地生鮮市場進貨。對國防大學2號院所有人員進行核酸檢測」。\n\n甚至還有網友發文爆料，北京國防大學被封，多家軍方醫院爆滿，包括武警醫院爆滿封院，軍方系統全面遭殃。\n\n北京武漢肺炎疫情持續快速蔓延，從「新發地批發市場」向北京全市的農貿市場輸送病源，自11日以來已累計106人確診病例，北京市官方15日宣布，北京全市社區防控工作進入「戰時狀態」，並展開「敲門行動」大排查；16日晚間，北京市政府舉行記者會，宣布北京市突發公共衛生事件應急響應級別由三級調至二級，並相應調整防控策略。\n\n相關新聞請見︰\n\n「武漢肺炎專區」請點此，更多相關訊息，帶您第一手掌握。\n\n不用抽 不用搶 現在用APP看新聞 保證天天中獎 點我下載APP 按我看活動辦法'],
#  ['user1_17',
#   '2020-06-24',
#   'https://news.ltn.com.tw/news/world/breakingnews/3197617',
#   '2020-06-14',
#   '武漢肺炎》北京警戒再提升！ 多地列為中、高風險地區',
#  ['https://news.ltn.com.tw/list/breakingnews/novelty',
#   '2020-06-24',
#   'https://news.ltn.com.tw/list/breakingnews/novelty',
#   '',
#   '',
#   ''],
#  ['https://auto.ltn.com.tw/',
#   '2020-06-24',
#   'https://auto.ltn.com.tw/',
#   '',
#   '',
#   ''],
#  ['https://news.ltn.com.tw/list/breakingnews/world',
#   '2020-06-24',
#   'https://news.ltn.com.tw/list/breakingnews/world',
#   '',
#   '',
#   ''],
#  ['https://news.ltn.com.tw/list/breakingnews/local',
#   '2020-06-24',
#   'https://news.ltn.com.tw/list/breakingnews/local',
#   '',
#   '',
#   ''],
#  ['https://health.ltn.com.tw/',
#   '2020-06-24',
#   'https://health.ltn.com.tw/',
#   '',
#   '',
#   ''],
#  ['https://ent.ltn.com.tw/',
#   '2020-06-24',
#   'https://ent.ltn.com.tw/',
#   '',
#   '',
#   ''],
#  ['user1_19',
#   '2020-06-24',
#   'https://ent.ltn.com.tw/news/breakingnews/3208328',
#   'None',
#   '台中三井LaLaport今動工 2022開幕270品牌進駐',
#   '']]

# %%
user_network_edges
# Out:
# [['https://www.chinatimes.com/', 'user1_1', '2020-06-23 00:22:33'],
#  ['user1_1', 'user1_2', '2020-06-23 00:22:40'],
#  ['user1_2',
#   'https://news.ltn.com.tw/list/breakingnews',
#   '2020-06-23 00:22:51'],
#  ['https://news.ltn.com.tw/list/breakingnews',
#   'https://sports.ltn.com.tw/',
#   '2020-06-23 00:23:02'],
#  ['https://sports.ltn.com.tw/',
#   'https://news.ltn.com.tw/list/breakingnews',
#   '2020-06-23 00:23:12'],
#  ['https://news.ltn.com.tw/list/breakingnews',
#   'https://sports.ltn.com.tw/',
#   '2020-06-23 00:24:06'],
#  ['https://sports.ltn.com.tw/', 'user1_3', '2020-06-23 00:25:47'],
#  ['user1_3', 'user1_4', '2020-06-23 00:25:57'],
#  ['user1_4', 'https://www.chinatimes.com/', '2020-06-24 14:46:35'],
#  ['https://www.chinatimes.com/', 'user1_5', '2020-06-24 14:46:41'],
#  ['user1_5', 'user1_6', '2020-06-24 14:46:51'],
#  ['user1_6', 'user1_7', '2020-06-24 14:46:53'],
#  ['user1_7',
#   'https://www.chinatimes.com/realtimenews/',
#   '2020-06-24 14:47:04'],
#  ['https://www.chinatimes.com/realtimenews/',
#   'https://covid-19.chinatimes.com/%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E,%E5%8F%B0%E7%81%A3',
#   '2020-06-24 14:47:08'],
#  ['https://covid-19.chinatimes.com/%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E,%E5%8F%B0%E7%81%A3',
#   'user1_8',
#   '2020-06-24 14:47:10'],
#  ['user1_8', 'user1_8', '2020-06-24 14:47:26'],
#  ['user1_8', 'user1_9', '2020-06-24 14:47:41'],
#  ['user1_9', 'https://www.ltn.com.tw/', '2020-06-24 14:47:51'],
#  ['https://www.ltn.com.tw/', 'user1_10', '2020-06-24 14:47:55'],
#  ['user1_10', 'user1_11', '2020-06-24 14:48:06'],
#  ['user1_11',
#   'https://news.ltn.com.tw/list/breakingnews',
#   '2020-06-24 14:48:09'],
#  ['https://news.ltn.com.tw/list/breakingnews',
#   'https://news.ltn.com.tw/list/breakingnews/popular',
#   '2020-06-24 14:48:19'],
#  ['https://news.ltn.com.tw/list/breakingnews/popular',
#   'https://sports.ltn.com.tw/',
#   '2020-06-24 14:48:21'],
#  ['https://sports.ltn.com.tw/',
#   'https://news.ltn.com.tw/list/breakingnews/politics',
#   '2020-06-24 14:48:24'],
#  ['https://news.ltn.com.tw/list/breakingnews/politics',
#   'https://news.ltn.com.tw/list/breakingnews/life',
#   '2020-06-24 14:48:25'],
#  ['https://news.ltn.com.tw/list/breakingnews/life',
#   'https://www.ltn.com.tw/',
#   '2020-06-24 20:22:26'],
#  ['https://www.ltn.com.tw/', 'user1_12', '2020-06-24 20:22:30'],
#  ['user1_12', 'https://market.ltn.com.tw/article/8382', '2020-06-24 20:22:39'],
#  ['https://market.ltn.com.tw/article/8382', 'user1_13', '2020-06-24 20:22:58'],
#  ['user1_13', 'user1_14', '2020-06-24 20:23:19'],
#  ['user1_14', 'user1_15', '2020-06-24 20:23:25'],
#  ['user1_15', 'user1_16', '2020-06-24 20:24:00'],
#  ['user1_16', 'user1_17', '2020-06-24 20:24:13'],
#  ['user1_17', 'user1_18', '2020-06-24 20:24:23'],
#  ['user1_18',
#   'https://news.ltn.com.tw/list/breakingnews/novelty',
#   '2020-06-24 20:24:27'],
#  ['https://news.ltn.com.tw/list/breakingnews/novelty',
#   'https://auto.ltn.com.tw/',
#   '2020-06-24 20:24:37'],
#  ['https://auto.ltn.com.tw/',
#   'https://news.ltn.com.tw/list/breakingnews/world',
#   '2020-06-24 20:24:45'],
#  ['https://news.ltn.com.tw/list/breakingnews/world',
#   'https://news.ltn.com.tw/list/breakingnews/local',
#   '2020-06-24 20:24:56'],
#  ['https://news.ltn.com.tw/list/breakingnews/local',
#   'https://health.ltn.com.tw/',
#   '2020-06-24 20:24:59'],
#  ['https://health.ltn.com.tw/',
#   'https://ent.ltn.com.tw/',
#   '2020-06-24 20:25:05'],
#  ['https://ent.ltn.com.tw/', 'user1_19', '2020-06-24 20:25:12']]

# %%
def draw_network(nodes, edges, TODAY_DATE):
    G = nx.Graph() 
    G.add_nodes_from(nodes) 
    G.add_edges_from(edges)
    nx.draw(G,
            pos = nx.spring_layout(G),
            node_color = 'blue',
            edge_color = 'black',
            with_labels = True,
            font_size =5,
            node_size =40)
    plt.savefig('./Networks_png/Network_%s.png' %(TODAY_DATE), dpi=300)
#     plt.show()

# %%
draw_network(nodes=[k[0] for k in user_network_nodes], edges=[[k[0], k[1]] for k in user_network_edges], TODAY_DATE=TODAY_DATE)

# %%
import utils_db

# %%
utils_db.insert_nodes_table('./user2.db', user_network_nodes)
utils_db.insert_edges_table('./user2.db', user_network_edges)
